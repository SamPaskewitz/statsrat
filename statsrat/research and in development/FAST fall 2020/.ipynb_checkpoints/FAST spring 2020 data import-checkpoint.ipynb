# %%
import numpy as np
import pandas as pd
import statsrat as sr
from statsrat import rw
from statsrat.expr.predef.cat import fast

# %%
# Indicate whether the learning model should be fit.
fit_model = True

# Define learning model.
model = rw.model(name = 'CompAct_eta0',
                 fbase = rw.fbase.elem,
                 fweight = rw.fweight.from_aux_norm,
                 lrate = rw.lrate.from_aux_norm,
                 aux = rw.aux.gradcomp_eta0)

# Define time limit for model fitting (in old R code was Inf, but is 10 by default in current code).
max_time = 120

# %%
(ds_spring2020, summary_spring2020) = fast.read_csv(path = 'fast_data_spring/learning',
                                                    x_col = ['cue1', 'cue2'],
                                                    resp_col = ['trial_resp.keys', 'test_resp.keys'],
                                                    resp_map = {'h' : 'cati', 'g' : 'catii', 'c' : 'cat1', 'm' : 'cat2', 's' : 'cat3', 'r' : 'cat4'},
                                                    ident_col = 'sonaID',
                                                    conf_col = 'conf_rating.response',
                                                    n_final = 8)


print(summary_spring2020)
# Out:
# string operation on non-string array
# string operation on non-string array
# string operation on non-string array
# string operation on non-string array
# string operation on non-string array
# string operation on non-string array
# wrong number of trials for file fast_data_spring/learning/20_spring_faces_2020_Jan_28_1526.csv
# trials found: 194
# trials expected: 204
# string operation on non-string array
# string operation on non-string array
# string operation on non-string array
# ['cue1', 'cue2']
# string operation on non-string array
# string operation on non-string array
# string operation on non-string array
# string operation on non-string array
# string operation on non-string array
# string operation on non-string array
# string operation on non-string array
# string operation on non-string array
# string operation on non-string array
# string operation on non-string array
# string operation on non-string array
# ['test_resp.keys']
# string operation on non-string array
# string operation on non-string array
# string operation on non-string array
# string operation on non-string array
# string operation on non-string array
# string operation on non-string array
# string operation on non-string array
# string operation on non-string array
# string operation on non-string array
# string operation on non-string array
# string operation on non-string array
# string operation on non-string array
# string operation on non-string array
# ['cue1', 'cue2']
# string operation on non-string array
# string operation on non-string array
# string operation on non-string array
# string operation on non-string array
# ['test_resp.keys']
# string operation on non-string array
# string operation on non-string array
# string operation on non-string array
# string operation on non-string array
# string operation on non-string array
# string operation on non-string array
# string operation on non-string array
# string operation on non-string array
# string operation on non-string array
# string operation on non-string array
# string operation on non-string array
# string operation on non-string array
# string operation on non-string array
# string operation on non-string array
# string operation on non-string array
# string operation on non-string array
# ['cue1', 'cue2']
# string operation on non-string array
# [109 109 109 109 109 109 109 109 109 109 109 109 109 109 109 109 109 109
#  109 109 109 109 109 109 109 109 109 109 109 109 109 109 109 109 109 109
#  109 109 109 109 109 109 109 109 109 109 109 109 109 109 109 109 109 109
#  109 109 109 109 109 109 109 109 109 109 109 109 109 109 109 109 109 109
#  109 109 109 109 109 109 109 109 109 109 109 109 109 109 109 109 109 109
#  109 109 109 109 109 109 109 109 109 109 109 109 109 109 109 109 109 109
#  109 109 109 109 109 109 109 109 109 109 109 109 109 109 109 109 109 109
#  109 109 109 109 109 109 109 109 109 109 109 109 109 109 109 109 109 109
#  109 109 109 109 109 109 109 109 109 109 109 109 109 109 109 109 109 109
#  109 109 109 109 109 109 109 109 109 109 109 109 109 109 109 109 109 109
#  109 109 109 109 109 109 109 109 109 109 109 109 109 109 109 109 109 109
#  109 109 109 109 109 109]
# string operation on non-string array
# string operation on non-string array
# string operation on non-string array
# string operation on non-string array
# string operation on non-string array
# string operation on non-string array
# string operation on non-string array
# ['cue1', 'cue2']
# string operation on non-string array
# string operation on non-string array
# string operation on non-string array
# string operation on non-string array
# string operation on non-string array
# string operation on non-string array
# string operation on non-string array
# string operation on non-string array
# string operation on non-string array
# string operation on non-string array
# string operation on non-string array
# string operation on non-string array
# string operation on non-string array
# string operation on non-string array
# string operation on non-string array
# string operation on non-string array
# string operation on non-string array
# string operation on non-string array
# string operation on non-string array
# string operation on non-string array
# string operation on non-string array
# string operation on non-string array
# string operation on non-string array
# string operation on non-string array
# string operation on non-string array
# string operation on non-string array
# string operation on non-string array
# string operation on non-string array
# string operation on non-string array
# string operation on non-string array
# string operation on non-string array
# string operation on non-string array
# string operation on non-string array
# string operation on non-string array
# string operation on non-string array
# string operation on non-string array
# string operation on non-string array
# string operation on non-string array
# string operation on non-string array
# string operation on non-string array
# string operation on non-string array
# string operation on non-string array
# string operation on non-string array
# string operation on non-string array
# string operation on non-string array
# string operation on non-string array
# string operation on non-string array
# string operation on non-string array
# string operation on non-string array
# string operation on non-string array
# string operation on non-string array
# string operation on non-string array
# string operation on non-string array
# string operation on non-string array
# ['cue1', 'cue2']
# string operation on non-string array
# ['cue1', 'cue2']
# string operation on non-string array
# string operation on non-string array
# string operation on non-string array
# string operation on non-string array
# string operation on non-string array
# ['cue1', 'cue2']
# string operation on non-string array
# string operation on non-string array
# string operation on non-string array
# string operation on non-string array
# string operation on non-string array
# string operation on non-string array
# string operation on non-string array
# string operation on non-string array
# string operation on non-string array
# ['test_resp.keys']
# string operation on non-string array
# string operation on non-string array
# string operation on non-string array
# string operation on non-string array
# string operation on non-string array
# string operation on non-string array
# string operation on non-string array
# string operation on non-string array
# ['cue1', 'cue2']
# string operation on non-string array
# string operation on non-string array
# string operation on non-string array
# string operation on non-string array
# string operation on non-string array
# string operation on non-string array
# string operation on non-string array
# ['cue1', 'cue2']
# ['cue1', 'cue2']
# string operation on non-string array
# string operation on non-string array
# string operation on non-string array
# string operation on non-string array
# string operation on non-string array
# string operation on non-string array
# string operation on non-string array
# string operation on non-string array
# The following files could not be read by Pandas:
# fast_data_spring/learning/20_spring_faces_2020_Jan_28_1526.csv
# fast_data_spring/learning/173_spring_faces_2020_Feb_27_0926.csv
# fast_data_spring/learning/165_spring_faces_2020_Feb_25_1140.csv
# fast_data_spring/learning/11_spring_faces_2020_Jan_28_1116.csv
# fast_data_spring/learning/41_spring_faces_2020_Jan_30_1316.csv
# fast_data_spring/learning/74_spring_faces_2020_Feb_06_0857.csv
# fast_data_spring/learning/143_spring_faces_2020_Feb_20_0859.csv
# fast_data_spring/learning/12_spring_faces_2020_Jan_28_1126.csv
# fast_data_spring/learning/113_spring_faces_2020_Feb_11_1523.csv
# fast_data_spring/learning/162_spring_faces_2020_Feb_25_0956.csv
# fast_data_spring/learning/16_spring_faces_2020_Jan_28_1449.csv
# fast_data_spring/learning/171_spring_faces_2020_Feb_25_1527.csv
# fast_data_spring/learning/57_spring_faces_2020_Feb_04_1029.csv
# fast_data_spring/learning/164_spring_faces_2020_Feb_25_1115.csv
# Participant ID (ident) could not be read from the following files:
# fast_data_spring/learning/90_spring_faces_2020_Feb_06_1320.csv
# fast_data_spring/learning/57_spring_faces_2020_Feb_04_1031.csv
# fast_data_spring/learning/151_spring_faces_2020_Feb_20_1213.csv
# fast_data_spring/learning/171_spring_faces_2020_Feb_25_1529.csv
# fast_data_spring/learning/72_spring_faces_2020_Feb_04_1554.csv
# fast_data_spring/learning/33_spring_faces_2020_Jan_30_1101.csv
# fast_data_spring/learning/15_spring_faces_2020_Jan_28_1418.csv
# fast_data_spring/learning/43_spring_faces_2020_Jan_30_1358.csv
# fast_data_spring/learning/168_spring_faces_2020_Feb_25_1353.csv
# fast_data_spring/learning/54_spring_faces_2020_Feb_04_0956.csv
# fast_data_spring/learning/69_spring_faces_2020_Feb_04_1457.csv
# fast_data_spring/learning/88_spring_faces_2020_Feb_06_1250.csv
# fast_data_spring/learning/121_spring_faces_2020_Feb_13_1209.csv
# fast_data_spring/learning/60_spring_faces_2020_Feb_04_1111.csv
# fast_data_spring/learning/9_spring_faces_2020_Jan_28_1057.csv
# fast_data_spring/learning/4_spring_faces_2020_Jan_28_0956.csv
# fast_data_spring/learning/122_spring_faces_2020_Feb_13_1324.csv
# fast_data_spring/learning/45_spring_faces_2020_Jan_30_1403.csv
# fast_data_spring/learning/123_spring_faces_2020_Feb_13_1347.csv
# fast_data_spring/learning/52_spring_faces_2020_Jan_30_1553.csv
# fast_data_spring/learning/110_spring_faces_2020_Feb_11_1409.csv
# fast_data_spring/learning/117_spring_faces_2020_Feb_13_1025.csv
# fast_data_spring/learning/140_spring_faces_2020_Feb_18_1520.csv
# fast_data_spring/learning/7_spring_faces_2020_Jan_28_1031.csv
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-3-a758043605ba> in <module>
# ----> 1 (ds_spring2020, summary_spring2020) = fast.read_csv(path = 'fast_data_spring/learning',
#       2                                                     x_col = ['cue1', 'cue2'],
#       3                                                     resp_col = ['trial_resp.keys', 'test_resp.keys'],
#       4                                                     resp_map = {'h' : 'cati', 'g' : 'catii', 'c' : 'cat1', 'm' : 'cat2', 's' : 'cat3', 'r' : 'cat4'},
#       5                                                     ident_col = 'participant',#'sonaID',
#
# ~/Dropbox/Research/Modeling/PhD thesis/statsrat/statsrat/expr/learn.py in read_csv(self, path, x_col, resp_col, resp_map, ident_col, conf_col, schedule, other_info, header, n_final)
#     372
#     373         # create summary data frame (each row corresponds to a participant)
# --> 374         summary = ds.drop_dims(['t', 'trial', 'x_name', 'u_name']).to_dataframe()
#     375         # add pct_correct
#     376         for i in range(n_stage):
#
# /opt/anaconda3/lib/python3.8/site-packages/xarray/core/dataset.py in drop_dims(self, drop_dims, errors)
#    3902             missing_dims = drop_dims - set(self.dims)
#    3903             if missing_dims:
# -> 3904                 raise ValueError(
#    3905                     "Dataset does not contain the dimensions: %s" % missing_dims
#    3906                 )
#
# ValueError: Dataset does not contain the dimensions: {'x_name', 'trial', 'u_name', 't'}

# %%
# Import survey data.
df_surveys = pd.read_csv('fast_data_spring/surveys/JonesSec9.csv')
# FINISH

# Only keep people whose surveys can be read.
index = summary_fall2020_inlab.index.isin(foo.index.values)
ds_fall2020_inlab = ds_fall2020_inlab[{'ident': index}]
    
if fit_model:
    # Fit model.
    bar = sr.fit_indv(model = model,
                      ds = ds_spring2020,
                      max_time = max_time)
    # Concatenate data frames.
    summary_spring2020 = pd.concat([summary_spring2020.loc[index], foo, bar], axis = 1)

# %%
print(summary_spring2020.shape[0])

print(summary_spring2020['rel_irl'].min())
print(summary_spring2020['rel_irl'].max())
print(summary_spring2020['rel_irl'].mean())

print(summary_spring2020['threat_benign_os'].min())
print(summary_spring2020['threat_benign_os'].max())
print(summary_spring2020['threat_benign_os'].mean())
