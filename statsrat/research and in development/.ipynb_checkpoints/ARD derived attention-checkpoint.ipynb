# %%
import numpy as np
import xarray as xr
import pandas as pd
import nlopt
import seaborn as sns
from statsrat import perform_oat, oat_grid, make_sim_data, learn_plot
from statsrat.expr.predef.cat import ibre, lrn_pred
from statsrat.rw.predef import smpr
import statsrat.bayes_regr as br
from statsrat.rw.fbase import elem, elem_intercept
from scipy import stats

# %%
#m = br.model(name = 'linear', fbase = elem, link = br.link.linear, tausq_inv_dist = br.tausq_inv_dist.constant)
#m = br.model(name = 'linear derived attention ARD', fbase = elem, link = br.link.linear, tausq_inv_dist = br.tausq_inv_dist.ard_drv_atn)
#m = br.model(name = 'multinomial probit', fbase = elem, link = br.link.multinomial_probit, tausq_inv_dist = br.tausq_inv_dist.constant)
m = br.model(name = 'multinomial probit derived attention ARD', fbase = elem, link = br.link.multinomial_probit, tausq_inv_dist = br.tausq_inv_dist.ard_drv_atn)

#par_val = [1, 5]
par_val = [-1, 10, 5]

print(m.pars)
trials = ibre.make_trials()
#trials = lrn_pred.make_trials()
ds = m.simulate(trials = trials, par_val = par_val)
# Out:
#                         min   max  default
# prior_tausq_inv_hpar0 -10.0   0.0     -2.0
# prior_tausq_inv_hpar1   1.0  11.0      3.0
# resp_scale              0.0  10.0      1.0

# %%
var = 'shrink_cond'
#print(np.round(ds['shrink_cond'].loc[{'t': range(10)}], 0))
learn_plot(ds, var)
# Out:
# <ggplot: (306247150)>

# %%
#var = 'mean_tausq_inv'
var = 'mean_tausq'
learn_plot(ds, var)
# Out:
# <ggplot: (305095843)>

# %%
var = 'mean_z'
index = ds.trial_name == 'i1.pr1 -> r1'
#index = ds.trial_name == 'i1.pc1 -> c1'
learn_plot(ds, var, sel = {'u_name': ['c1', 'r1'], 't': index})
# Out:
# <ggplot: (305158235)>

# %%
var = 'mean_w'
#var = 'mean_wsq'
learn_plot(ds, var, sel = {'f_name': ['pc1', 'pr1', 'i1'], 'u_name': ['c1', 'r1']})
# Out:
# <ggplot: (306242820)>

# %%
# ordinal adequacy test (OAT) for the IBRE

n = 20
max_time = 60
#algorithm = nlopt.GN_DIRECT_L
#algorithm = nlopt.GN_AGS
algorithm = nlopt.GN_ORIG_DIRECT
#algorithm = nlopt.GD_STOGO

#m = br.model(name = 'linear', fbase = elem, link = br.link.linear, tausq_inv_dist = br.tausq_inv_dist.constant)
#m = br.model(name = 'linear derived attention ARD', fbase = elem, link = br.link.linear, tausq_inv_dist = br.tausq_inv_dist.ard_drv_atn)
m = br.model(name = 'multinomial probit', fbase = elem_intercept, link = br.link.multinomial_probit, tausq_inv_dist = br.tausq_inv_dist.constant)
#m = br.model(name = 'multinomial probit derived attention ARD', fbase = elem, link = br.link.multinomial_probit, tausq_inv_dist = br.tausq_inv_dist.ard_drv_atn)

oat_result = perform_oat(m, ibre, minimize = False, n = n, max_time = max_time, algorithm = algorithm)
print(oat_result[0])
print(oat_result[1])
# Out:
# Maximizing OAT score.
# [50.005  5.   ]
# [83.33433333  5.        ]
# [16.67566667  5.        ]
# [94.44411111  5.        ]
# [72.22455556  5.        ]
# [61.11477778  5.        ]
# [38.89522222  5.        ]
# [98.14737037  5.        ]
# [90.74085185  5.        ]
# [27.78544444  5.        ]
# [5.56588889 5.        ]
# [99.38179012  5.        ]
# [96.91295062  5.        ]
# [9.26914815 5.        ]
# [1.86262963 5.        ]
# [87.03759259  5.        ]
# [79.63107407  5.        ]
# [3.09704938 5.        ]
# [0.62820988 5.        ]
# [0.62820988 5.        ]
# [1.09111728 5.        ]
# [0.16530247 5.        ]
# [0.011 5.   ]
# [0.12672685 5.        ]
# [0.03993171 5.        ]
# [0.01823293 5.        ]
# [0.01280823 5.        ]
# [0.01145206 5.        ]
# [0.01111301 5.        ]
# [0.01102825 5.        ]
# [0.01100706 5.        ]
# [0.01100177 5.        ]
# [0.01100044 5.        ]
# [0.01100011 5.        ]
# [0.01100003 5.        ]
# [0.01100001 5.        ]
# [0.011 5.   ]
#      tausq_inv      mean     lower     upper
# max      0.011 -0.064238 -0.074404 -0.054072
#   schedule          trial_name u_name  mean_resp
# 0   design  pc1.pr1 -> nothing     c1   0.413333
# 1   design  pc1.pr1 -> nothing     c2   0.118544
# 2   design  pc1.pr1 -> nothing     r1   0.352525
# 3   design  pc1.pr1 -> nothing     r2   0.115598
# 4   design  pc2.pr2 -> nothing     c1   0.117143
# 5   design  pc2.pr2 -> nothing     c2   0.417781
# 6   design  pc2.pr2 -> nothing     r1   0.114964
# 7   design  pc2.pr2 -> nothing     r2   0.350112

# %%
#m = br.model(name = 'linear', fbase = elem, link = br.link.linear, tausq_inv_dist = br.tausq_inv_dist.constant)
#m = br.model(name = 'linear derived attention ARD', fbase = elem, link = br.link.linear, tausq_inv_dist = br.tausq_inv_dist.ard_drv_atn)
m = br.model(name = 'multinomial probit', fbase = elem, link = br.link.multinomial_probit, tausq_inv_dist = br.tausq_inv_dist.constant)

free_par = 'tausq_inv'
fixed_values = {'resp_scale': 5}
#free_par = 'u_var'
#fixed_values = {'prior_tausq_inv_hpar0': -10, 'prior_tausq_inv_hpar1': 2, 'resp_scale': 5}

df = oat_grid(m,
              ibre,
              free_par = free_par,
              fixed_values = fixed_values,
              n_points = 5)
sns.relplot(x = free_par, y = 'oat_score', data = df)

# %%
# ordinal adequacy test (OAT) for learned predictiveness
n = 20
max_time = 60
#algorithm = nlopt.GN_DIRECT_L
#algorithm = nlopt.GN_AGS
algorithm = nlopt.GN_ORIG_DIRECT
#algorithm = nlopt.GD_STOGO

#m = br.model(name = 'linear', fbase = elem, link = br.link.linear, tausq_inv_dist = br.tausq_inv_dist.constant)
#m = br.model(name = 'linear derived attention ARD', fbase = elem, link = br.link.linear, tausq_inv_dist = br.tausq_inv_dist.ard_drv_atn)
m = br.model(name = 'multinomial probit', fbase = elem, link = br.link.multinomial_probit, tausq_inv_dist = br.tausq_inv_dist.constant)

oat_result = perform_oat(m, lrn_pred, n = n, max_time = max_time, algorithm = algorithm, minimize = False)
print(oat_result[0])
print(oat_result[1])
# Out:
# Maximizing OAT score.
# [50.005  5.   ]
# [83.33433333  5.        ]
# [16.67566667  5.        ]
# [50.005  5.   ]
# [75.002  5.   ]
#      tausq_inv  mean  lower  upper
# max     75.002   0.0    0.0    0.0
#   schedule      trial_name u_name  mean_resp
# 0   design  a.c -> nothing   cat3   0.581723
# 1   design  a.c -> nothing   cat4   0.418277
# 2   design  b.d -> nothing   cat3   0.418277
# 3   design  b.d -> nothing   cat4   0.581723
# 4   design  v.x -> nothing   cat3   0.581723
# 5   design  v.x -> nothing   cat4   0.418277
# 6   design  w.y -> nothing   cat3   0.418277
# 7   design  w.y -> nothing   cat4   0.581723
